# %%
import json
import requests
import pandas as pd
import numpy as np

# %%
base_url = "http://stats.nba.com/stats/leaguedashptstats"
season="2014-15"
season_type="Playoffs"
player_or_team="Player"
measure_type="CatchShoot"
parameters={"Season": season,
            "SeasonType": season_type,
            "PlayerOrTeam": player_or_team,
             "PtMeasureType": measure_type
            }
data=requests.get(base_url,params=parameters)

# %%
USER_AGENT = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/47.0.2526.73 Chrome/47.0.2526.73 Safari/537.36"
REFERER = "http://stats.nba.com/scores/"

# %%
def get_sportvu_data_for_stat(season, season_type, player_or_team, measure_type, start_date="", end_date="", last_n_games=0, league_id="00", month=0, opponent_team_id=0, por_round=0, per_mode="Totals", team_id=0, outcome="", location="", season_segment="", vs_conference="", vs_division="", game_scope="", player_experience="", player_position="", starter_bench=""):
    parameters = {
                    "DateFrom": start_date,
                    "DateTo": end_date,
                    "PlayerOrTeam": player_or_team,
                    "PtMeasureType": measure_type,
                    "Season": season,
                    "SeasonType": season_type,
                    "LastNGames": last_n_games,
                    "LeagueID": league_id,
                    "Month": month,
                    "OpponentTeamID": opponent_team_id,
                    "PORound": por_round,
                    "PerMode": per_mode,
                    "TeamID": team_id,
                    "Outcome": outcome,
                    "Location": location,
                    "SeasonSegment": season_segment,
                    "VsConference": vs_conference,
                    "VsDivision": vs_division,
                    "GameScope": game_scope,
                    "PlayerExperience": player_experience,
                    "PlayerPosition": player_position,
                    "StarterBench": starter_bench
    }
    base_url = "http://stats.nba.com/stats/leaguedashptstats"
    return get_data_from_url_with_parameters(base_url, parameters, 0)

# %%
def get_data_from_url_with_parameters(base_url, parameters, index):
    measure_type=parameters["PtMeasureType"]
    response = requests.get(base_url, params=parameters, headers={'User-Agent': USER_AGENT, 'referer': REFERER})
    data = response.json()
    headers = data['resultSets'][index]['headers']
    rows = data['resultSets'][index]['rowSet']
    #return [dict(zip(headers, row)) for row in rows]
    df = pd.DataFrame(rows)
    df.columns = headers
    df = df.set_index(['PLAYER_ID', 'TEAM_ABBREVIATION','PLAYER_NAME','TEAM_ID'])
    df.columns = ['{}_{}'.format(measure_type, x) for x in df.columns]
    return df

# %%
data=get_sportvu_data_for_stat(season="2014-15",
season_type="Regular Season",
player_or_team="Player",
measure_type="Rebounding")

# %%
measures=["CatchShoot", 
"Defense",
"Drives",
"Passing",
"PullUpShot",
"Rebounding",
"Efficiency",
"SpeedDistance",
"ElbowTouch",
"PaintTouch",
"PostTouch",
"Possessions"]

# %%
def sportvu_df(season, measure_types,season_type="Regular Season",
player_or_team="Player"):
    sportvu=None
    for m in measure_types:
        print(m)
        input_df=get_sportvu_data_for_stat(season,
        season_type,
        player_or_team,
        measure_type=m)
        if sportvu is None:
            sportvu = input_df
        else:
            sportvu = pd.merge(sportvu,
                               input_df,
                               how='inner',
                               left_index=True,
                               right_index=True)
            print(sportvu.shape)
    sportvu.to_csv('raw_{}'.format(season))
    return sportvu

# %%
sportvu_data=sportvu_df(season='2014-15',measure_types=measures)
# Out:
# CatchShoot
# Defense
# (492, 22)
# Drives
# (492, 43)
# Passing
# (492, 57)
# PullUpShot
# (492, 69)
# Rebounding
# (492, 100)
# Efficiency
# (492, 118)
# SpeedDistance
# (492, 129)
# ElbowTouch
# (492, 151)
# PaintTouch
# (492, 173)
# PostTouch
# (492, 195)
# Possessions
# (492, 212)

# %%
sportvu = None
for suffix, input_df in sportsvu_data.items():
    print(suffix)
    if sportvu is None:
        sportvu = input_df
    else:
        sportvu = pd.merge(sportvu,
                           input_df,
                           how='inner',
                           left_index=True,
                           right_index=True)
        print(sportvu.size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-afa0844ee559> in <module>()
#       1 sportvu = None
# ----> 2 for suffix, input_df in sportsvu_data.items():
#       3     print(suffix)
#       4     if sportvu is None:
#       5         sportvu = input_df
#
# NameError: name 'sportsvu_data' is not defined

# %%
# Out:
# CatchShoot
# Defense
# (492, 22)
# Drives
# (492, 43)
# Passing
# (492, 57)
# PullUpShot
# (492, 69)
# Rebounding
# (492, 100)
# Efficiency
# (492, 118)
# SpeedDistance
# (492, 129)
# ElbowTouch
# (492, 151)
# PaintTouch
# (492, 173)
# PostTouch
# (492, 195)
# Possessions
# (492, 212)

# %%
season='2013-14'
sportvu_data1.to_csv('raw_{}'.format(season))

# %%
sportvu_df(season='2013-14',measure_types=measures)
# Out:
# CatchShoot
# Defense
# (482, 22)
# Drives
# (482, 43)
# Passing
# (482, 57)
# PullUpShot
# (482, 69)
# Rebounding
# (482, 100)
# Efficiency
# (482, 118)
# SpeedDistance
# (482, 129)
# ElbowTouch
# (482, 151)
# PaintTouch
# (482, 173)
# PostTouch
# (482, 195)
# Possessions
# (482, 212)
#                                                               CatchShoot_GP  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751             53
# 951       MIA               Ray Allen             1610612748             73
# 959       LAL               Steve Nash            1610612747             15
# 965       OKC               Derek Fisher          1610612760             81
# 977       LAL               Kobe Bryant           1610612747              6
# 979       GSW               Jermaine O'Neal       1610612744             43
# 1495      SAS               Tim Duncan            1610612759             74
# 1497      DET               Chauncey Billups      1610612765             19
# 1536      LAC               Stephen Jackson       1610612746              9
# 1712      LAC               Antawn Jamison        1610612746             22
# 1713      DAL               Vince Carter          1610612742             81
# 1717      DAL               Dirk Nowitzki         1610612742             80
# 1718      BKN               Paul Pierce           1610612751             74
# 1733      WAS               Al Harrington         1610612764             33
# 1737      CHI               Nazr Mohammed         1610612741             80
# 1740      MIA               Rashard Lewis         1610612748             60
# 1882      ATL               Elton Brand           1610612737             72
# 1889      WAS               Andre Miller          1610612764             57
# 1890      DAL               Shawn Marion          1610612742             76
# 1891      BKN               Jason Terry           1610612751             34
# 1897      NYK               Metta World Peace     1610612752             29
# 1905      BKN               Andrei Kirilenko      1610612751             44
# 1938      SAS               Manu Ginobili         1610612759             68
# 2030      NYK               Kenyon Martin         1610612752             32
# 2034      MEM               Mike Miller           1610612763             82
# 2037      LAC               Jamal Crawford        1610612746             69
# 2045      LAC               Hedo Turkoglu         1610612746             38
# 2199      NYK               Tyson Chandler        1610612752             55
# 2200      LAL               Pau Gasol             1610612747             60
# 2203      MIA               Shane Battier         1610612748             73
# ...                                                                     ...
# 203499    DAL               Shane Larkin          1610612742             48
# 203500    OKC               Steven Adams          1610612760             81
# 203501    NYK               Tim Hardaway Jr.      1610612752             81
# 203502    DET               Tony Mitchell         1610612765             21
# 203503    CHI               Tony Snell            1610612741             77
# 203504    UTA               Trey Burke            1610612762             70
# 203505    BOS               Vander Blue           1610612738              3
# 203506    ORL               Victor Oladipo        1610612753             80
# 203507    MIL               Giannis Antetokounmpo 1610612749             76
# 203508    CLE               Sergey Karasev        1610612739             22
# 203513    CHI               Erik Murphy           1610612741             24
# 203515    BOS               Phil Pressey          1610612738             75
# 203517    GSW               Nemanja Nedovic       1610612744             23
# 203519    PHI               Adonis Thomas         1610612755              6
# 203521    CLE               Matthew Dellavedova   1610612739             72
# 203524    IND               Solomon Hill          1610612754             28
# 203527    LAL               Ryan Kelly            1610612747             59
# 203539    DAL               Gal Mekel             1610612742             31
# 203540    DET               Gigi Datome           1610612765             34
# 203543    BOS               Vitor Faverani        1610612738             37
# 203544    ATL               Pero Antic            1610612737             49
# 203545    MIL               Miroslav Raduljica    1610612749             48
# 203546    UTA               Ian Clark             1610612762             23
# 203548    LAL               Elias Harris          1610612747              2
# 203552    CLE               Seth Curry            1610612739              2
# 203561    PHI               Brandon Davies        1610612755             51
# 203569    BOS               Chris Babb            1610612738             14
# 203584    HOU               Troy Daniels          1610612745              5
# 203810    PHI               Casper Ware           1610612755              9
# 203816    CLE               Scotty Hopson         1610612739              2
#
#                                                               CatchShoot_W  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751            26
# 951       MIA               Ray Allen             1610612748            47
# 959       LAL               Steve Nash            1610612747             4
# 965       OKC               Derek Fisher          1610612760            59
# 977       LAL               Kobe Bryant           1610612747             2
# 979       GSW               Jermaine O'Neal       1610612744            26
# 1495      SAS               Tim Duncan            1610612759            56
# 1497      DET               Chauncey Billups      1610612765             7
# 1536      LAC               Stephen Jackson       1610612746             6
# 1712      LAC               Antawn Jamison        1610612746            15
# 1713      DAL               Vince Carter          1610612742            49
# 1717      DAL               Dirk Nowitzki         1610612742            48
# 1718      BKN               Paul Pierce           1610612751            41
# 1733      WAS               Al Harrington         1610612764            20
# 1737      CHI               Nazr Mohammed         1610612741            47
# 1740      MIA               Rashard Lewis         1610612748            41
# 1882      ATL               Elton Brand           1610612737            34
# 1889      WAS               Andre Miller          1610612764            32
# 1890      DAL               Shawn Marion          1610612742            44
# 1891      BKN               Jason Terry           1610612751            16
# 1897      NYK               Metta World Peace     1610612752            10
# 1905      BKN               Andrei Kirilenko      1610612751            29
# 1938      SAS               Manu Ginobili         1610612759            52
# 2030      NYK               Kenyon Martin         1610612752            13
# 2034      MEM               Mike Miller           1610612763            50
# 2037      LAC               Jamal Crawford        1610612746            47
# 2045      LAC               Hedo Turkoglu         1610612746            27
# 2199      NYK               Tyson Chandler        1610612752            24
# 2200      LAL               Pau Gasol             1610612747            21
# 2203      MIA               Shane Battier         1610612748            49
# ...                                                                    ...
# 203499    DAL               Shane Larkin          1610612742            26
# 203500    OKC               Steven Adams          1610612760            59
# 203501    NYK               Tim Hardaway Jr.      1610612752            37
# 203502    DET               Tony Mitchell         1610612765             6
# 203503    CHI               Tony Snell            1610612741            46
# 203504    UTA               Trey Burke            1610612762            24
# 203505    BOS               Vander Blue           1610612738             1
# 203506    ORL               Victor Oladipo        1610612753            23
# 203507    MIL               Giannis Antetokounmpo 1610612749            14
# 203508    CLE               Sergey Karasev        1610612739             7
# 203513    CHI               Erik Murphy           1610612741            13
# 203515    BOS               Phil Pressey          1610612738            23
# 203517    GSW               Nemanja Nedovic       1610612744            16
# 203519    PHI               Adonis Thomas         1610612755             2
# 203521    CLE               Matthew Dellavedova   1610612739            29
# 203524    IND               Solomon Hill          1610612754            17
# 203527    LAL               Ryan Kelly            1610612747            15
# 203539    DAL               Gal Mekel             1610612742            18
# 203540    DET               Gigi Datome           1610612765             9
# 203543    BOS               Vitor Faverani        1610612738            13
# 203544    ATL               Pero Antic            1610612737            23
# 203545    MIL               Miroslav Raduljica    1610612749             7
# 203546    UTA               Ian Clark             1610612762             3
# 203548    LAL               Elias Harris          1610612747             1
# 203552    CLE               Seth Curry            1610612739             1
# 203561    PHI               Brandon Davies        1610612755            15
# 203569    BOS               Chris Babb            1610612738             3
# 203584    HOU               Troy Daniels          1610612745             3
# 203810    PHI               Casper Ware           1610612755             3
# 203816    CLE               Scotty Hopson         1610612739             2
#
#                                                               CatchShoot_L  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751            27
# 951       MIA               Ray Allen             1610612748            26
# 959       LAL               Steve Nash            1610612747            11
# 965       OKC               Derek Fisher          1610612760            22
# 977       LAL               Kobe Bryant           1610612747             4
# 979       GSW               Jermaine O'Neal       1610612744            17
# 1495      SAS               Tim Duncan            1610612759            18
# 1497      DET               Chauncey Billups      1610612765            12
# 1536      LAC               Stephen Jackson       1610612746             3
# 1712      LAC               Antawn Jamison        1610612746             7
# 1713      DAL               Vince Carter          1610612742            32
# 1717      DAL               Dirk Nowitzki         1610612742            32
# 1718      BKN               Paul Pierce           1610612751            33
# 1733      WAS               Al Harrington         1610612764            13
# 1737      CHI               Nazr Mohammed         1610612741            33
# 1740      MIA               Rashard Lewis         1610612748            19
# 1882      ATL               Elton Brand           1610612737            38
# 1889      WAS               Andre Miller          1610612764            25
# 1890      DAL               Shawn Marion          1610612742            32
# 1891      BKN               Jason Terry           1610612751            18
# 1897      NYK               Metta World Peace     1610612752            19
# 1905      BKN               Andrei Kirilenko      1610612751            15
# 1938      SAS               Manu Ginobili         1610612759            16
# 2030      NYK               Kenyon Martin         1610612752            19
# 2034      MEM               Mike Miller           1610612763            32
# 2037      LAC               Jamal Crawford        1610612746            22
# 2045      LAC               Hedo Turkoglu         1610612746            11
# 2199      NYK               Tyson Chandler        1610612752            31
# 2200      LAL               Pau Gasol             1610612747            39
# 2203      MIA               Shane Battier         1610612748            24
# ...                                                                    ...
# 203499    DAL               Shane Larkin          1610612742            22
# 203500    OKC               Steven Adams          1610612760            22
# 203501    NYK               Tim Hardaway Jr.      1610612752            44
# 203502    DET               Tony Mitchell         1610612765            15
# 203503    CHI               Tony Snell            1610612741            31
# 203504    UTA               Trey Burke            1610612762            46
# 203505    BOS               Vander Blue           1610612738             2
# 203506    ORL               Victor Oladipo        1610612753            57
# 203507    MIL               Giannis Antetokounmpo 1610612749            62
# 203508    CLE               Sergey Karasev        1610612739            15
# 203513    CHI               Erik Murphy           1610612741            11
# 203515    BOS               Phil Pressey          1610612738            52
# 203517    GSW               Nemanja Nedovic       1610612744             7
# 203519    PHI               Adonis Thomas         1610612755             4
# 203521    CLE               Matthew Dellavedova   1610612739            43
# 203524    IND               Solomon Hill          1610612754            11
# 203527    LAL               Ryan Kelly            1610612747            44
# 203539    DAL               Gal Mekel             1610612742            13
# 203540    DET               Gigi Datome           1610612765            25
# 203543    BOS               Vitor Faverani        1610612738            24
# 203544    ATL               Pero Antic            1610612737            26
# 203545    MIL               Miroslav Raduljica    1610612749            41
# 203546    UTA               Ian Clark             1610612762            20
# 203548    LAL               Elias Harris          1610612747             1
# 203552    CLE               Seth Curry            1610612739             1
# 203561    PHI               Brandon Davies        1610612755            36
# 203569    BOS               Chris Babb            1610612738            11
# 203584    HOU               Troy Daniels          1610612745             2
# 203810    PHI               Casper Ware           1610612755             6
# 203816    CLE               Scotty Hopson         1610612739             0
#
#                                                               CatchShoot_MIN  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751          1090.0
# 951       MIA               Ray Allen             1610612748          1936.0
# 959       LAL               Steve Nash            1610612747           313.0
# 965       OKC               Derek Fisher          1610612760          1428.0
# 977       LAL               Kobe Bryant           1610612747           177.0
# 979       GSW               Jermaine O'Neal       1610612744           862.0
# 1495      SAS               Tim Duncan            1610612759          2158.0
# 1497      DET               Chauncey Billups      1610612765           309.0
# 1536      LAC               Stephen Jackson       1610612746           107.0
# 1712      LAC               Antawn Jamison        1610612746           248.0
# 1713      DAL               Vince Carter          1610612742          1973.0
# 1717      DAL               Dirk Nowitzki         1610612742          2628.0
# 1718      BKN               Paul Pierce           1610612751          2071.0
# 1733      WAS               Al Harrington         1610612764           497.0
# 1737      CHI               Nazr Mohammed         1610612741           562.0
# 1740      MIA               Rashard Lewis         1610612748           971.0
# 1882      ATL               Elton Brand           1610612737          1392.0
# 1889      WAS               Andre Miller          1610612764           968.0
# 1890      DAL               Shawn Marion          1610612742          2409.0
# 1891      BKN               Jason Terry           1610612751           544.0
# 1897      NYK               Metta World Peace     1610612752           388.0
# 1905      BKN               Andrei Kirilenko      1610612751           836.0
# 1938      SAS               Manu Ginobili         1610612759          1550.0
# 2030      NYK               Kenyon Martin         1610612752           633.0
# 2034      MEM               Mike Miller           1610612763          1707.0
# 2037      LAC               Jamal Crawford        1610612746          2094.0
# 2045      LAC               Hedo Turkoglu         1610612746           392.0
# 2199      NYK               Tyson Chandler        1610612752          1662.0
# 2200      LAL               Pau Gasol             1610612747          1884.0
# 2203      MIA               Shane Battier         1610612748          1468.0
# ...                                                                      ...
# 203499    DAL               Shane Larkin          1610612742           489.0
# 203500    OKC               Steven Adams          1610612760          1197.0
# 203501    NYK               Tim Hardaway Jr.      1610612752          1875.0
# 203502    DET               Tony Mitchell         1610612765            79.0
# 203503    CHI               Tony Snell            1610612741          1231.0
# 203504    UTA               Trey Burke            1610612762          2262.0
# 203505    BOS               Vander Blue           1610612738            15.0
# 203506    ORL               Victor Oladipo        1610612753          2487.0
# 203507    MIL               Giannis Antetokounmpo 1610612749          1880.0
# 203508    CLE               Sergey Karasev        1610612739           156.0
# 203513    CHI               Erik Murphy           1610612741            62.0
# 203515    BOS               Phil Pressey          1610612738          1132.0
# 203517    GSW               Nemanja Nedovic       1610612744           134.0
# 203519    PHI               Adonis Thomas         1610612755            38.0
# 203521    CLE               Matthew Dellavedova   1610612739          1271.0
# 203524    IND               Solomon Hill          1610612754           226.0
# 203527    LAL               Ryan Kelly            1610612747          1312.0
# 203539    DAL               Gal Mekel             1610612742           292.0
# 203540    DET               Gigi Datome           1610612765           238.0
# 203543    BOS               Vitor Faverani        1610612738           488.0
# 203544    ATL               Pero Antic            1610612737           902.0
# 203545    MIL               Miroslav Raduljica    1610612749           465.0
# 203546    UTA               Ian Clark             1610612762           172.0
# 203548    LAL               Elias Harris          1610612747            11.0
# 203552    CLE               Seth Curry            1610612739            13.0
# 203561    PHI               Brandon Davies        1610612755           575.0
# 203569    BOS               Chris Babb            1610612738           132.0
# 203584    HOU               Troy Daniels          1610612745            75.0
# 203810    PHI               Casper Ware           1610612755           116.0
# 203816    CLE               Scotty Hopson         1610612739             7.0
#
#                                                               CatchShoot_CATCH_SHOOT_FGM  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751                          63
# 951       MIA               Ray Allen             1610612748                         124
# 959       LAL               Steve Nash            1610612747                           7
# 965       OKC               Derek Fisher          1610612760                          70
# 977       LAL               Kobe Bryant           1610612747                           2
# 979       GSW               Jermaine O'Neal       1610612744                          10
# 1495      SAS               Tim Duncan            1610612759                         101
# 1497      DET               Chauncey Billups      1610612765                          10
# 1536      LAC               Stephen Jackson       1610612746                           1
# 1712      LAC               Antawn Jamison        1610612746                          11
# 1713      DAL               Vince Carter          1610612742                         110
# 1717      DAL               Dirk Nowitzki         1610612742                         268
# 1718      BKN               Paul Pierce           1610612751                         116
# 1733      WAS               Al Harrington         1610612764                          35
# 1737      CHI               Nazr Mohammed         1610612741                           9
# 1740      MIA               Rashard Lewis         1610612748                          49
# 1882      ATL               Elton Brand           1610612737                          76
# 1889      WAS               Andre Miller          1610612764                          10
# 1890      DAL               Shawn Marion          1610612742                          78
# 1891      BKN               Jason Terry           1610612751                          31
# 1897      NYK               Metta World Peace     1610612752                          15
# 1905      BKN               Andrei Kirilenko      1610612751                           2
# 1938      SAS               Manu Ginobili         1610612759                          82
# 2030      NYK               Kenyon Martin         1610612752                          12
# 2034      MEM               Mike Miller           1610612763                         133
# 2037      LAC               Jamal Crawford        1610612746                         124
# 2045      LAC               Hedo Turkoglu         1610612746                          18
# 2199      NYK               Tyson Chandler        1610612752                          11
# 2200      LAL               Pau Gasol             1610612747                          97
# 2203      MIA               Shane Battier         1610612748                          66
# ...                                                                                  ...
# 203499    DAL               Shane Larkin          1610612742                           9
# 203500    OKC               Steven Adams          1610612760                           4
# 203501    NYK               Tim Hardaway Jr.      1610612752                         126
# 203502    DET               Tony Mitchell         1610612765                           0
# 203503    CHI               Tony Snell            1610612741                          62
# 203504    UTA               Trey Burke            1610612762                         108
# 203505    BOS               Vander Blue           1610612738                           0
# 203506    ORL               Victor Oladipo        1610612753                          59
# 203507    MIL               Giannis Antetokounmpo 1610612749                          32
# 203508    CLE               Sergey Karasev        1610612739                           5
# 203513    CHI               Erik Murphy           1610612741                           1
# 203515    BOS               Phil Pressey          1610612738                          24
# 203517    GSW               Nemanja Nedovic       1610612744                           2
# 203519    PHI               Adonis Thomas         1610612755                           1
# 203521    CLE               Matthew Dellavedova   1610612739                          56
# 203524    IND               Solomon Hill          1610612754                           5
# 203527    LAL               Ryan Kelly            1610612747                          54
# 203539    DAL               Gal Mekel             1610612742                           6
# 203540    DET               Gigi Datome           1610612765                          13
# 203543    BOS               Vitor Faverani        1610612738                          21
# 203544    ATL               Pero Antic            1610612737                          63
# 203545    MIL               Miroslav Raduljica    1610612749                           1
# 203546    UTA               Ian Clark             1610612762                          11
# 203548    LAL               Elias Harris          1610612747                           0
# 203552    CLE               Seth Curry            1610612739                           0
# 203561    PHI               Brandon Davies        1610612755                           7
# 203569    BOS               Chris Babb            1610612738                           5
# 203584    HOU               Troy Daniels          1610612745                           8
# 203810    PHI               Casper Ware           1610612755                           4
# 203816    CLE               Scotty Hopson         1610612739                           0
#
#                                                               CatchShoot_CATCH_SHOOT_FGA  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751                         131
# 951       MIA               Ray Allen             1610612748                         303
# 959       LAL               Steve Nash            1610612747                          16
# 965       OKC               Derek Fisher          1610612760                         166
# 977       LAL               Kobe Bryant           1610612747                          10
# 979       GSW               Jermaine O'Neal       1610612744                          23
# 1495      SAS               Tim Duncan            1610612759                         266
# 1497      DET               Chauncey Billups      1610612765                          28
# 1536      LAC               Stephen Jackson       1610612746                          13
# 1712      LAC               Antawn Jamison        1610612746                          55
# 1713      DAL               Vince Carter          1610612742                         275
# 1717      DAL               Dirk Nowitzki         1610612742                         572
# 1718      BKN               Paul Pierce           1610612751                         295
# 1733      WAS               Al Harrington         1610612764                          97
# 1737      CHI               Nazr Mohammed         1610612741                          33
# 1740      MIA               Rashard Lewis         1610612748                         135
# 1882      ATL               Elton Brand           1610612737                         155
# 1889      WAS               Andre Miller          1610612764                          18
# 1890      DAL               Shawn Marion          1610612742                         193
# 1891      BKN               Jason Terry           1610612751                          82
# 1897      NYK               Metta World Peace     1610612752                          49
# 1905      BKN               Andrei Kirilenko      1610612751                          24
# 1938      SAS               Manu Ginobili         1610612759                         217
# 2030      NYK               Kenyon Martin         1610612752                          34
# 2034      MEM               Mike Miller           1610612763                         287
# 2037      LAC               Jamal Crawford        1610612746                         336
# 2045      LAC               Hedo Turkoglu         1610612746                          38
# 2199      NYK               Tyson Chandler        1610612752                          32
# 2200      LAL               Pau Gasol             1610612747                         226
# 2203      MIA               Shane Battier         1610612748                         187
# ...                                                                                  ...
# 203499    DAL               Shane Larkin          1610612742                          30
# 203500    OKC               Steven Adams          1610612760                          11
# 203501    NYK               Tim Hardaway Jr.      1610612752                         332
# 203502    DET               Tony Mitchell         1610612765                           2
# 203503    CHI               Tony Snell            1610612741                         177
# 203504    UTA               Trey Burke            1610612762                         302
# 203505    BOS               Vander Blue           1610612738                           1
# 203506    ORL               Victor Oladipo        1610612753                         170
# 203507    MIL               Giannis Antetokounmpo 1610612749                         109
# 203508    CLE               Sergey Karasev        1610612739                          22
# 203513    CHI               Erik Murphy           1610612741                           6
# 203515    BOS               Phil Pressey          1610612738                          83
# 203517    GSW               Nemanja Nedovic       1610612744                          11
# 203519    PHI               Adonis Thomas         1610612755                           7
# 203521    CLE               Matthew Dellavedova   1610612739                         138
# 203524    IND               Solomon Hill          1610612754                          21
# 203527    LAL               Ryan Kelly            1610612747                         154
# 203539    DAL               Gal Mekel             1610612742                          17
# 203540    DET               Gigi Datome           1610612765                          54
# 203543    BOS               Vitor Faverani        1610612738                          55
# 203544    ATL               Pero Antic            1610612737                         179
# 203545    MIL               Miroslav Raduljica    1610612749                          10
# 203546    UTA               Ian Clark             1610612762                          28
# 203548    LAL               Elias Harris          1610612747                           0
# 203552    CLE               Seth Curry            1610612739                           0
# 203561    PHI               Brandon Davies        1610612755                          29
# 203569    BOS               Chris Babb            1610612738                          25
# 203584    HOU               Troy Daniels          1610612745                          19
# 203810    PHI               Casper Ware           1610612755                          11
# 203816    CLE               Scotty Hopson         1610612739                           1
#
#                                                               CatchShoot_CATCH_SHOOT_FG_PCT  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751                          0.481
# 951       MIA               Ray Allen             1610612748                          0.409
# 959       LAL               Steve Nash            1610612747                          0.438
# 965       OKC               Derek Fisher          1610612760                          0.422
# 977       LAL               Kobe Bryant           1610612747                          0.200
# 979       GSW               Jermaine O'Neal       1610612744                          0.435
# 1495      SAS               Tim Duncan            1610612759                          0.380
# 1497      DET               Chauncey Billups      1610612765                          0.357
# 1536      LAC               Stephen Jackson       1610612746                          0.077
# 1712      LAC               Antawn Jamison        1610612746                          0.200
# 1713      DAL               Vince Carter          1610612742                          0.400
# 1717      DAL               Dirk Nowitzki         1610612742                          0.469
# 1718      BKN               Paul Pierce           1610612751                          0.393
# 1733      WAS               Al Harrington         1610612764                          0.361
# 1737      CHI               Nazr Mohammed         1610612741                          0.273
# 1740      MIA               Rashard Lewis         1610612748                          0.363
# 1882      ATL               Elton Brand           1610612737                          0.490
# 1889      WAS               Andre Miller          1610612764                          0.556
# 1890      DAL               Shawn Marion          1610612742                          0.404
# 1891      BKN               Jason Terry           1610612751                          0.378
# 1897      NYK               Metta World Peace     1610612752                          0.306
# 1905      BKN               Andrei Kirilenko      1610612751                          0.083
# 1938      SAS               Manu Ginobili         1610612759                          0.378
# 2030      NYK               Kenyon Martin         1610612752                          0.353
# 2034      MEM               Mike Miller           1610612763                          0.463
# 2037      LAC               Jamal Crawford        1610612746                          0.369
# 2045      LAC               Hedo Turkoglu         1610612746                          0.474
# 2199      NYK               Tyson Chandler        1610612752                          0.344
# 2200      LAL               Pau Gasol             1610612747                          0.429
# 2203      MIA               Shane Battier         1610612748                          0.353
# ...                                                                                     ...
# 203499    DAL               Shane Larkin          1610612742                          0.300
# 203500    OKC               Steven Adams          1610612760                          0.364
# 203501    NYK               Tim Hardaway Jr.      1610612752                          0.380
# 203502    DET               Tony Mitchell         1610612765                          0.000
# 203503    CHI               Tony Snell            1610612741                          0.350
# 203504    UTA               Trey Burke            1610612762                          0.358
# 203505    BOS               Vander Blue           1610612738                          0.000
# 203506    ORL               Victor Oladipo        1610612753                          0.347
# 203507    MIL               Giannis Antetokounmpo 1610612749                          0.294
# 203508    CLE               Sergey Karasev        1610612739                          0.227
# 203513    CHI               Erik Murphy           1610612741                          0.167
# 203515    BOS               Phil Pressey          1610612738                          0.289
# 203517    GSW               Nemanja Nedovic       1610612744                          0.182
# 203519    PHI               Adonis Thomas         1610612755                          0.143
# 203521    CLE               Matthew Dellavedova   1610612739                          0.406
# 203524    IND               Solomon Hill          1610612754                          0.238
# 203527    LAL               Ryan Kelly            1610612747                          0.351
# 203539    DAL               Gal Mekel             1610612742                          0.353
# 203540    DET               Gigi Datome           1610612765                          0.241
# 203543    BOS               Vitor Faverani        1610612738                          0.382
# 203544    ATL               Pero Antic            1610612737                          0.352
# 203545    MIL               Miroslav Raduljica    1610612749                          0.100
# 203546    UTA               Ian Clark             1610612762                          0.393
# 203548    LAL               Elias Harris          1610612747                          0.000
# 203552    CLE               Seth Curry            1610612739                          0.000
# 203561    PHI               Brandon Davies        1610612755                          0.241
# 203569    BOS               Chris Babb            1610612738                          0.200
# 203584    HOU               Troy Daniels          1610612745                          0.421
# 203810    PHI               Casper Ware           1610612755                          0.364
# 203816    CLE               Scotty Hopson         1610612739                          0.000
#
#                                                               CatchShoot_CATCH_SHOOT_PTS  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751                         126
# 951       MIA               Ray Allen             1610612748                         356
# 959       LAL               Steve Nash            1610612747                          20
# 965       OKC               Derek Fisher          1610612760                         200
# 977       LAL               Kobe Bryant           1610612747                           5
# 979       GSW               Jermaine O'Neal       1610612744                          20
# 1495      SAS               Tim Duncan            1610612759                         202
# 1497      DET               Chauncey Billups      1610612765                          28
# 1536      LAC               Stephen Jackson       1610612746                           3
# 1712      LAC               Antawn Jamison        1610612746                          30
# 1713      DAL               Vince Carter          1610612742                         320
# 1717      DAL               Dirk Nowitzki         1610612742                         652
# 1718      BKN               Paul Pierce           1610612751                         335
# 1733      WAS               Al Harrington         1610612764                         102
# 1737      CHI               Nazr Mohammed         1610612741                          18
# 1740      MIA               Rashard Lewis         1610612748                         142
# 1882      ATL               Elton Brand           1610612737                         152
# 1889      WAS               Andre Miller          1610612764                          28
# 1890      DAL               Shawn Marion          1610612742                         213
# 1891      BKN               Jason Terry           1610612751                          90
# 1897      NYK               Metta World Peace     1610612752                          43
# 1905      BKN               Andrei Kirilenko      1610612751                           5
# 1938      SAS               Manu Ginobili         1610612759                         236
# 2030      NYK               Kenyon Martin         1610612752                          24
# 2034      MEM               Mike Miller           1610612763                         367
# 2037      LAC               Jamal Crawford        1610612746                         355
# 2045      LAC               Hedo Turkoglu         1610612746                          52
# 2199      NYK               Tyson Chandler        1610612752                          22
# 2200      LAL               Pau Gasol             1610612747                         198
# 2203      MIA               Shane Battier         1610612748                         198
# ...                                                                                  ...
# 203499    DAL               Shane Larkin          1610612742                          26
# 203500    OKC               Steven Adams          1610612760                           8
# 203501    NYK               Tim Hardaway Jr.      1610612752                         364
# 203502    DET               Tony Mitchell         1610612765                           0
# 203503    CHI               Tony Snell            1610612741                         174
# 203504    UTA               Trey Burke            1610612762                         305
# 203505    BOS               Vander Blue           1610612738                           0
# 203506    ORL               Victor Oladipo        1610612753                         171
# 203507    MIL               Giannis Antetokounmpo 1610612749                          90
# 203508    CLE               Sergey Karasev        1610612739                          14
# 203513    CHI               Erik Murphy           1610612741                           2
# 203515    BOS               Phil Pressey          1610612738                          71
# 203517    GSW               Nemanja Nedovic       1610612744                           6
# 203519    PHI               Adonis Thomas         1610612755                           3
# 203521    CLE               Matthew Dellavedova   1610612739                         160
# 203524    IND               Solomon Hill          1610612754                          15
# 203527    LAL               Ryan Kelly            1610612747                         153
# 203539    DAL               Gal Mekel             1610612742                          17
# 203540    DET               Gigi Datome           1610612765                          33
# 203543    BOS               Vitor Faverani        1610612738                          54
# 203544    ATL               Pero Antic            1610612737                         179
# 203545    MIL               Miroslav Raduljica    1610612749                           2
# 203546    UTA               Ian Clark             1610612762                          32
# 203548    LAL               Elias Harris          1610612747                           0
# 203552    CLE               Seth Curry            1610612739                           0
# 203561    PHI               Brandon Davies        1610612755                          16
# 203569    BOS               Chris Babb            1610612738                          15
# 203584    HOU               Troy Daniels          1610612745                          24
# 203810    PHI               Casper Ware           1610612755                          12
# 203816    CLE               Scotty Hopson         1610612739                           0
#
#                                                               CatchShoot_CATCH_SHOOT_FG3M  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751                            0
# 951       MIA               Ray Allen             1610612748                          108
# 959       LAL               Steve Nash            1610612747                            6
# 965       OKC               Derek Fisher          1610612760                           60
# 977       LAL               Kobe Bryant           1610612747                            1
# 979       GSW               Jermaine O'Neal       1610612744                            0
# 1495      SAS               Tim Duncan            1610612759                            0
# 1497      DET               Chauncey Billups      1610612765                            8
# 1536      LAC               Stephen Jackson       1610612746                            1
# 1712      LAC               Antawn Jamison        1610612746                            8
# 1713      DAL               Vince Carter          1610612742                          100
# 1717      DAL               Dirk Nowitzki         1610612742                          116
# 1718      BKN               Paul Pierce           1610612751                          103
# 1733      WAS               Al Harrington         1610612764                           32
# 1737      CHI               Nazr Mohammed         1610612741                            0
# 1740      MIA               Rashard Lewis         1610612748                           44
# 1882      ATL               Elton Brand           1610612737                            0
# 1889      WAS               Andre Miller          1610612764                            8
# 1890      DAL               Shawn Marion          1610612742                           57
# 1891      BKN               Jason Terry           1610612751                           28
# 1897      NYK               Metta World Peace     1610612752                           13
# 1905      BKN               Andrei Kirilenko      1610612751                            1
# 1938      SAS               Manu Ginobili         1610612759                           72
# 2030      NYK               Kenyon Martin         1610612752                            0
# 2034      MEM               Mike Miller           1610612763                          101
# 2037      LAC               Jamal Crawford        1610612746                          107
# 2045      LAC               Hedo Turkoglu         1610612746                           16
# 2199      NYK               Tyson Chandler        1610612752                            0
# 2200      LAL               Pau Gasol             1610612747                            4
# 2203      MIA               Shane Battier         1610612748                           66
# ...                                                                                   ...
# 203499    DAL               Shane Larkin          1610612742                            8
# 203500    OKC               Steven Adams          1610612760                            0
# 203501    NYK               Tim Hardaway Jr.      1610612752                          112
# 203502    DET               Tony Mitchell         1610612765                            0
# 203503    CHI               Tony Snell            1610612741                           50
# 203504    UTA               Trey Burke            1610612762                           89
# 203505    BOS               Vander Blue           1610612738                            0
# 203506    ORL               Victor Oladipo        1610612753                           53
# 203507    MIL               Giannis Antetokounmpo 1610612749                           26
# 203508    CLE               Sergey Karasev        1610612739                            4
# 203513    CHI               Erik Murphy           1610612741                            0
# 203515    BOS               Phil Pressey          1610612738                           23
# 203517    GSW               Nemanja Nedovic       1610612744                            2
# 203519    PHI               Adonis Thomas         1610612755                            1
# 203521    CLE               Matthew Dellavedova   1610612739                           48
# ...
# 1938      SAS               Manu Ginobili         1610612759                            0.319
# 2030      NYK               Kenyon Martin         1610612752                            0.095
# 2034      MEM               Mike Miller           1610612763                            0.322
# 2037      LAC               Jamal Crawford        1610612746                            0.292
# 2045      LAC               Hedo Turkoglu         1610612746                            0.111
# 2199      NYK               Tyson Chandler        1610612752                            0.170
# 2200      LAL               Pau Gasol             1610612747                            0.356
# 2203      MIA               Shane Battier         1610612748                            0.033
# ...                                                                                       ...
# 203499    DAL               Shane Larkin          1610612742                            0.333
# 203500    OKC               Steven Adams          1610612760                            0.197
# 203501    NYK               Tim Hardaway Jr.      1610612752                            0.366
# 203502    DET               Tony Mitchell         1610612765                            0.000
# 203503    CHI               Tony Snell            1610612741                            0.588
# 203504    UTA               Trey Burke            1610612762                            0.306
# 203505    BOS               Vander Blue           1610612738                            0.000
# 203506    ORL               Victor Oladipo        1610612753                            0.090
# 203507    MIL               Giannis Antetokounmpo 1610612749                            0.149
# 203508    CLE               Sergey Karasev        1610612739                            0.667
# 203513    CHI               Erik Murphy           1610612741                            0.000
# 203515    BOS               Phil Pressey          1610612738                            0.074
# 203517    GSW               Nemanja Nedovic       1610612744                            0.000
# 203519    PHI               Adonis Thomas         1610612755                            0.000
# 203521    CLE               Matthew Dellavedova   1610612739                            0.250
# 203524    IND               Solomon Hill          1610612754                            0.000
# 203527    LAL               Ryan Kelly            1610612747                            0.576
# 203539    DAL               Gal Mekel             1610612742                            0.000
# 203540    DET               Gigi Datome           1610612765                            0.750
# 203543    BOS               Vitor Faverani        1610612738                            0.200
# 203544    ATL               Pero Antic            1610612737                            0.174
# 203545    MIL               Miroslav Raduljica    1610612749                            0.184
# 203546    UTA               Ian Clark             1610612762                            0.000
# 203548    LAL               Elias Harris          1610612747                            0.000
# 203552    CLE               Seth Curry            1610612739                            0.000
# 203561    PHI               Brandon Davies        1610612755                            0.125
# 203569    BOS               Chris Babb            1610612738                            0.000
# 203584    HOU               Troy Daniels          1610612745                            0.000
# 203810    PHI               Casper Ware           1610612755                            0.000
# 203816    CLE               Scotty Hopson         1610612739                            0.000
#
#                                                               Possessions_PTS_PER_POST_TOUCH  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751                           0.657
# 951       MIA               Ray Allen             1610612748                           0.523
# 959       LAL               Steve Nash            1610612747                           0.667
# 965       OKC               Derek Fisher          1610612760                           0.364
# 977       LAL               Kobe Bryant           1610612747                           0.000
# 979       GSW               Jermaine O'Neal       1610612744                           0.977
# 1495      SAS               Tim Duncan            1610612759                           0.852
# 1497      DET               Chauncey Billups      1610612765                           0.000
# 1536      LAC               Stephen Jackson       1610612746                           0.000
# 1712      LAC               Antawn Jamison        1610612746                           1.235
# 1713      DAL               Vince Carter          1610612742                           0.408
# 1717      DAL               Dirk Nowitzki         1610612742                           0.895
# 1718      BKN               Paul Pierce           1610612751                           0.579
# 1733      WAS               Al Harrington         1610612764                           0.857
# 1737      CHI               Nazr Mohammed         1610612741                           0.733
# 1740      MIA               Rashard Lewis         1610612748                           0.490
# 1882      ATL               Elton Brand           1610612737                           0.668
# 1889      WAS               Andre Miller          1610612764                           0.317
# 1890      DAL               Shawn Marion          1610612742                           0.754
# 1891      BKN               Jason Terry           1610612751                           0.333
# 1897      NYK               Metta World Peace     1610612752                           0.444
# 1905      BKN               Andrei Kirilenko      1610612751                           0.808
# 1938      SAS               Manu Ginobili         1610612759                           1.017
# 2030      NYK               Kenyon Martin         1610612752                           1.034
# 2034      MEM               Mike Miller           1610612763                           0.276
# 2037      LAC               Jamal Crawford        1610612746                           0.697
# 2045      LAC               Hedo Turkoglu         1610612746                           0.900
# 2199      NYK               Tyson Chandler        1610612752                           1.153
# 2200      LAL               Pau Gasol             1610612747                           0.818
# 2203      MIA               Shane Battier         1610612748                           0.780
# ...                                                                                      ...
# 203499    DAL               Shane Larkin          1610612742                           0.800
# 203500    OKC               Steven Adams          1610612760                           0.615
# 203501    NYK               Tim Hardaway Jr.      1610612752                           0.667
# 203502    DET               Tony Mitchell         1610612765                           0.778
# 203503    CHI               Tony Snell            1610612741                           0.600
# 203504    UTA               Trey Burke            1610612762                           0.714
# 203505    BOS               Vander Blue           1610612738                           0.000
# 203506    ORL               Victor Oladipo        1610612753                           0.774
# 203507    MIL               Giannis Antetokounmpo 1610612749                           0.612
# 203508    CLE               Sergey Karasev        1610612739                           1.000
# 203513    CHI               Erik Murphy           1610612741                           0.667
# 203515    BOS               Phil Pressey          1610612738                           0.000
# 203517    GSW               Nemanja Nedovic       1610612744                           0.667
# 203519    PHI               Adonis Thomas         1610612755                           2.000
# 203521    CLE               Matthew Dellavedova   1610612739                           0.706
# 203524    IND               Solomon Hill          1610612754                           0.667
# 203527    LAL               Ryan Kelly            1610612747                           0.881
# 203539    DAL               Gal Mekel             1610612742                           0.500
# 203540    DET               Gigi Datome           1610612765                           1.000
# 203543    BOS               Vitor Faverani        1610612738                           0.775
# 203544    ATL               Pero Antic            1610612737                           0.602
# 203545    MIL               Miroslav Raduljica    1610612749                           0.909
# 203546    UTA               Ian Clark             1610612762                           0.000
# 203548    LAL               Elias Harris          1610612747                           0.000
# 203552    CLE               Seth Curry            1610612739                           0.000
# 203561    PHI               Brandon Davies        1610612755                           0.788
# 203569    BOS               Chris Babb            1610612738                           2.000
# 203584    HOU               Troy Daniels          1610612745                           0.000
# 203810    PHI               Casper Ware           1610612755                           1.200
# 203816    CLE               Scotty Hopson         1610612739                           0.000
#
#                                                               Possessions_PTS_PER_PAINT_TOUCH
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME           TEAM_ID
# 708       BKN               Kevin Garnett         1610612751                            0.741
# 951       MIA               Ray Allen             1610612748                            0.525
# 959       LAL               Steve Nash            1610612747                            0.667
# 965       OKC               Derek Fisher          1610612760                            0.444
# 977       LAL               Kobe Bryant           1610612747                            0.667
# 979       GSW               Jermaine O'Neal       1610612744                            1.011
# 1495      SAS               Tim Duncan            1610612759                            0.874
# 1497      DET               Chauncey Billups      1610612765                            0.000
# 1536      LAC               Stephen Jackson       1610612746                            0.000
# 1712      LAC               Antawn Jamison        1610612746                            1.333
# 1713      DAL               Vince Carter          1610612742                            0.771
# 1717      DAL               Dirk Nowitzki         1610612742                            0.930
# 1718      BKN               Paul Pierce           1610612751                            0.600
# 1733      WAS               Al Harrington         1610612764                            0.684
# 1737      CHI               Nazr Mohammed         1610612741                            0.583
# 1740      MIA               Rashard Lewis         1610612748                            0.625
# 1882      ATL               Elton Brand           1610612737                            0.682
# 1889      WAS               Andre Miller          1610612764                            0.423
# 1890      DAL               Shawn Marion          1610612742                            0.890
# 1891      BKN               Jason Terry           1610612751                            0.000
# 1897      NYK               Metta World Peace     1610612752                            0.857
# 1905      BKN               Andrei Kirilenko      1610612751                            1.000
# 1938      SAS               Manu Ginobili         1610612759                            1.039
# 2030      NYK               Kenyon Martin         1610612752                            0.840
# 2034      MEM               Mike Miller           1610612763                            0.261
# 2037      LAC               Jamal Crawford        1610612746                            0.818
# 2045      LAC               Hedo Turkoglu         1610612746                            0.875
# 2199      NYK               Tyson Chandler        1610612752                            1.158
# 2200      LAL               Pau Gasol             1610612747                            0.899
# 2203      MIA               Shane Battier         1610612748                            0.970
# ...                                                                                       ...
# 203499    DAL               Shane Larkin          1610612742                            0.500
# 203500    OKC               Steven Adams          1610612760                            0.644
# 203501    NYK               Tim Hardaway Jr.      1610612752                            1.091
# 203502    DET               Tony Mitchell         1610612765                            0.556
# 203503    CHI               Tony Snell            1610612741                            0.800
# 203504    UTA               Trey Burke            1610612762                            0.667
# 203505    BOS               Vander Blue           1610612738                            0.000
# 203506    ORL               Victor Oladipo        1610612753                            0.780
# 203507    MIL               Giannis Antetokounmpo 1610612749                            0.716
# 203508    CLE               Sergey Karasev        1610612739                            1.333
# 203513    CHI               Erik Murphy           1610612741                            0.800
# 203515    BOS               Phil Pressey          1610612738                            0.000
# 203517    GSW               Nemanja Nedovic       1610612744                            1.000
# 203519    PHI               Adonis Thomas         1610612755                            2.000
# 203521    CLE               Matthew Dellavedova   1610612739                            0.889
# 203524    IND               Solomon Hill          1610612754                            2.000
# 203527    LAL               Ryan Kelly            1610612747                            0.813
# 203539    DAL               Gal Mekel             1610612742                            1.000
# 203540    DET               Gigi Datome           1610612765                            1.333
# 203543    BOS               Vitor Faverani        1610612738                            0.833
# 203544    ATL               Pero Antic            1610612737                            0.571
# 203545    MIL               Miroslav Raduljica    1610612749                            1.012
# 203546    UTA               Ian Clark             1610612762                            0.000
# 203548    LAL               Elias Harris          1610612747                            0.000
# 203552    CLE               Seth Curry            1610612739                            0.000
# 203561    PHI               Brandon Davies        1610612755                            0.712
# 203569    BOS               Chris Babb            1610612738                            1.000
# 203584    HOU               Troy Daniels          1610612745                            0.000
# 203810    PHI               Casper Ware           1610612755                            1.000
# 203816    CLE               Scotty Hopson         1610612739                            0.000
#
# [482 rows x 212 columns]

# %%
season='2013-14'
nba_data=pd.read_csv('raw_2013-14')

# %%
nba_data=nba_data.set_index(['PLAYER_ID', 'TEAM_ABBREVIATION','PLAYER_NAME','TEAM_ID'])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn import (manifold,  decomposition, lda, random_projection)

# %%
player_names=[x[2] for x in nba_data.index]
team_names=[x[1] for x in nba_data.index]

# %%
nba_data.head()
# Out:
#                                                       CatchShoot_GP  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751             53
# 951       MIA               Ray Allen     1610612748             73
# 959       LAL               Steve Nash    1610612747             15
# 965       OKC               Derek Fisher  1610612760             81
# 977       LAL               Kobe Bryant   1610612747              6
#
#                                                       CatchShoot_W  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751            26
# 951       MIA               Ray Allen     1610612748            47
# 959       LAL               Steve Nash    1610612747             4
# 965       OKC               Derek Fisher  1610612760            59
# 977       LAL               Kobe Bryant   1610612747             2
#
#                                                       CatchShoot_L  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751            27
# 951       MIA               Ray Allen     1610612748            26
# 959       LAL               Steve Nash    1610612747            11
# 965       OKC               Derek Fisher  1610612760            22
# 977       LAL               Kobe Bryant   1610612747             4
#
#                                                       CatchShoot_MIN  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751          1090.0
# 951       MIA               Ray Allen     1610612748          1936.0
# 959       LAL               Steve Nash    1610612747           313.0
# 965       OKC               Derek Fisher  1610612760          1428.0
# 977       LAL               Kobe Bryant   1610612747           177.0
#
#                                                       CatchShoot_CATCH_SHOOT_FGM  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                          63
# 951       MIA               Ray Allen     1610612748                         124
# 959       LAL               Steve Nash    1610612747                           7
# 965       OKC               Derek Fisher  1610612760                          70
# 977       LAL               Kobe Bryant   1610612747                           2
#
#                                                       CatchShoot_CATCH_SHOOT_FGA  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                         131
# 951       MIA               Ray Allen     1610612748                         303
# 959       LAL               Steve Nash    1610612747                          16
# 965       OKC               Derek Fisher  1610612760                         166
# 977       LAL               Kobe Bryant   1610612747                          10
#
#                                                       CatchShoot_CATCH_SHOOT_FG_PCT  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                          0.481
# 951       MIA               Ray Allen     1610612748                          0.409
# 959       LAL               Steve Nash    1610612747                          0.438
# 965       OKC               Derek Fisher  1610612760                          0.422
# 977       LAL               Kobe Bryant   1610612747                          0.200
#
#                                                       CatchShoot_CATCH_SHOOT_PTS  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                         126
# 951       MIA               Ray Allen     1610612748                         356
# 959       LAL               Steve Nash    1610612747                          20
# 965       OKC               Derek Fisher  1610612760                         200
# 977       LAL               Kobe Bryant   1610612747                           5
#
#                                                       CatchShoot_CATCH_SHOOT_FG3M  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                            0
# 951       MIA               Ray Allen     1610612748                          108
# 959       LAL               Steve Nash    1610612747                            6
# 965       OKC               Derek Fisher  1610612760                           60
# 977       LAL               Kobe Bryant   1610612747                            1
#
#                                                       CatchShoot_CATCH_SHOOT_FG3A  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                            2
# 951       MIA               Ray Allen     1610612748                          270
# 959       LAL               Steve Nash    1610612747                           13
# 965       OKC               Derek Fisher  1610612760                          148
# 977       LAL               Kobe Bryant   1610612747                            8
#
#                                                                    ...                 \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID                  ...
# 708       BKN               Kevin Garnett 1610612751               ...
# 951       MIA               Ray Allen     1610612748               ...
# 959       LAL               Steve Nash    1610612747               ...
# 965       OKC               Derek Fisher  1610612760               ...
# 977       LAL               Kobe Bryant   1610612747               ...
#
#                                                       Possessions_TIME_OF_POSS  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                      45.8
# 951       MIA               Ray Allen     1610612748                      78.1
# 959       LAL               Steve Nash    1610612747                      60.5
# 965       OKC               Derek Fisher  1610612760                     122.2
# 977       LAL               Kobe Bryant   1610612747                      33.9
#
#                                                       Possessions_AVG_SEC_PER_TOUCH  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                           1.19
# 951       MIA               Ray Allen     1610612748                           1.94
# 959       LAL               Steve Nash    1610612747                           4.57
# 965       OKC               Derek Fisher  1610612760                           3.37
# 977       LAL               Kobe Bryant   1610612747                           4.39
#
#                                                       Possessions_AVG_DRIB_PER_TOUCH  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                            0.24
# 951       MIA               Ray Allen     1610612748                            1.42
# 959       LAL               Steve Nash    1610612747                            5.21
# 965       OKC               Derek Fisher  1610612760                            3.25
# 977       LAL               Kobe Bryant   1610612747                            3.77
#
#                                                       Possessions_PTS_PER_TOUCH  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                      0.147
# 951       MIA               Ray Allen     1610612748                      0.290
# 959       LAL               Steve Nash    1610612747                      0.128
# 965       OKC               Derek Fisher  1610612760                      0.196
# 977       LAL               Kobe Bryant   1610612747                      0.179
#
#                                                       Possessions_ELBOW_TOUCHES  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                        210
# 951       MIA               Ray Allen     1610612748                         89
# 959       LAL               Steve Nash    1610612747                          9
# 965       OKC               Derek Fisher  1610612760                        114
# 977       LAL               Kobe Bryant   1610612747                         31
#
#                                                       Possessions_POST_TOUCHES  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                       137
# 951       MIA               Ray Allen     1610612748                        44
# 959       LAL               Steve Nash    1610612747                         3
# 965       OKC               Derek Fisher  1610612760                        11
# 977       LAL               Kobe Bryant   1610612747                         6
#
#                                                       Possessions_PAINT_TOUCHES  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                        116
# 951       MIA               Ray Allen     1610612748                         40
# 959       LAL               Steve Nash    1610612747                          3
# 965       OKC               Derek Fisher  1610612760                          9
# 977       LAL               Kobe Bryant   1610612747                          6
#
#                                                       Possessions_PTS_PER_ELBOW_TOUCH  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                            0.143
# 951       MIA               Ray Allen     1610612748                            0.315
# 959       LAL               Steve Nash    1610612747                            0.000
# 965       OKC               Derek Fisher  1610612760                            0.184
# 977       LAL               Kobe Bryant   1610612747                            0.387
#
#                                                       Possessions_PTS_PER_POST_TOUCH  \
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                           0.657
# 951       MIA               Ray Allen     1610612748                           0.523
# 959       LAL               Steve Nash    1610612747                           0.667
# 965       OKC               Derek Fisher  1610612760                           0.364
# 977       LAL               Kobe Bryant   1610612747                           0.000
#
#                                                       Possessions_PTS_PER_PAINT_TOUCH
# PLAYER_ID TEAM_ABBREVIATION PLAYER_NAME   TEAM_ID
# 708       BKN               Kevin Garnett 1610612751                            0.741
# 951       MIA               Ray Allen     1610612748                            0.525
# 959       LAL               Steve Nash    1610612747                            0.667
# 965       OKC               Derek Fisher  1610612760                            0.444
# 977       LAL               Kobe Bryant   1610612747                            0.667
#
# [5 rows x 212 columns]

# %%
#nba_data=nba_data.fillna(nba_data.mean(skipna=True))
#nba_data1=nba_data.convert_objects(convert_numeric=True)
nba_data=nba_data[nba_data['CatchShoot_GP']>40]
nba_data.shape
# Out:
# (337, 212)

# %%
player_names=[x[2] for x in nba_data.index]
team_names=[x[1] for x in nba_data.index]

# %%
scaler=StandardScaler()
nba_data=scaler.fit_transform(nba_data)
nba_data=pd.DataFrame(nba_data)

# %%
def clustering(data,year,k_clusters=7):
      center_file=''.join(["nba_centers_",year,".csv"])
      kmeans=KMeans(k_clusters).fit(data)
      centers=kmeans.cluster_centers_
      np.savetxt(center_file,centers)
      return(kmeans)

# %%
corr = nba_data.T.corr()
X = corr.as_matrix()
    
X_reduced = TruncatedSVD(n_components=10, random_state=0).fit_transform(X)

method='TSNE'
year='2013-14'
if(method=='TSNE'):
    tsne = manifold.TSNE(n_components=2, perplexity=40, verbose=2)
    X_tsne = tsne.fit_transform(X_reduced)
#      
kmeans=clustering(data=X_tsne,year=year,k_clusters=7)
df_projected = pd.DataFrame(X_tsne)
df_projected['player'] = player_names
df_projected['team'] = team_names
df_projected['cluster']=kmeans.labels_[0:df_projected.shape[0]]
df_projected.columns = ['x', 'y', 'player', 'team','cluster']
df_projected.to_csv('projected_2013-14', index=False)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 337 / 337
# [t-SNE] Mean sigma: 2.176658
# [t-SNE] Iteration 25: error = 0.6946407, gradient norm = 0.0163737
# [t-SNE] Iteration 50: error = 0.7601568, gradient norm = 0.0179642
# [t-SNE] Iteration 75: error = 0.5878504, gradient norm = 0.0108830
# [t-SNE] Iteration 100: error = 0.8125876, gradient norm = 0.0166604
# [t-SNE] Error after 100 iterations with early exaggeration: 0.812588
# [t-SNE] Iteration 125: error = 0.5987321, gradient norm = 0.0106252
# [t-SNE] Iteration 150: error = 0.7731693, gradient norm = 0.0155650
# [t-SNE] Iteration 175: error = 1.4314015, gradient norm = 0.0254308
# [t-SNE] Iteration 175: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 175 iterations: 1.431401

# %% [raw]
# # Draw the figure using R.

# %%
library(data.table) 
library(scatterD3) 
library(d3heatmap)
library(ggplot2) 
library(ggrepel) 
library(htmlwidgets)

file_path='projected_2013-14'
similarity<- function(year){
    print(file_path)
    dt <- fread(file_path, header=TRUE) # an error arise if read_csv is useddt
    dt=dt[team!='total']
       
    tooltips <- paste("<strong>", dt$player,"</strong><br /><strong>", dt$team, "</strong><br />") 
    p <- scatterD3(x = dt$x, y = dt$y, lab = dt$player, col_var=dt$team, symbol_var=dt$cluters, point_opacity = 0.7, tooltip_text = tooltips, col_lab = "Team", symbol_lab = "Cluster", width=1000, height=1000) 
    saveWidget(p, paste('nba_player_similarity',year,'.html'))
    print(paste(year,"_saved"))
}

# %%
similarity('2013-14')
# Out:
# [1] "projected_2013-14"
# [1] "2013-14 _saved"
